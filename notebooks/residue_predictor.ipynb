# %%
from pathlib import Path
from src.data import load_data

data_path = Path("../data")

(
    chemical_table,
    crop_table,
    application_table,
    weather_table,
    residue_table
) = load_data(data_path)
